# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
api_call_1 = pd.read_csv('./doce_octubre/doce_octubre_1.csv')
api_call_2 = pd.read_csv('./doce_octubre/doce_octubre_2.csv')
api_call_3 = pd.read_csv('./doce_octubre/doce_octubre_3.csv')
api_call_4 = pd.read_csv('./doce_octubre/doce_octubre_4.csv')
api_call_5 = pd.read_csv('./doce_octubre/doce_octubre_5.csv')
api_call_6 = pd.read_csv('./doce_octubre/doce_octubre_6.csv')
api_call_7 = pd.read_csv('./doce_octubre/doce_octubre_7.csv')
api_call_8 = pd.read_csv('./doce_octubre/doce_octubre_8.csv')
api_call_9 = pd.read_csv('./doce_octubre/doce_octubre_9.csv')
api_call_10 = pd.read_csv('./doce_octubre/doce_octubre_10.csv')
api_call_11 = pd.read_csv('./doce_octubre/doce_octubre_11.csv')
api_call_12 = pd.read_csv('./doce_octubre/doce_octubre_12.csv')
api_call_13 = pd.read_csv('./doce_octubre/doce_octubre_13.csv')
api_call_14 = pd.read_csv('./doce_octubre/doce_octubre_14.csv')
api_call_15 = pd.read_csv('./doce_octubre/doce_octubre_15.csv')
api_call_16 = pd.read_csv('./doce_octubre/doce_octubre_16.csv')
api_call_17 = pd.read_csv('./doce_octubre/doce_octubre_17.csv')
api_call_18 = pd.read_csv('./doce_octubre/doce_octubre_18.csv')
api_call_19 = pd.read_csv('./doce_octubre/doce_octubre_19.csv')
api_call_20 = pd.read_csv('./doce_octubre/doce_octubre_20.csv')
api_call_21 = pd.read_csv('./doce_octubre/doce_octubre_21.csv')
api_call_22 = pd.read_csv('./doce_octubre/doce_octubre_22.csv')
api_call_23 = pd.read_csv('./doce_octubre/doce_octubre_23.csv')
api_call_24 = pd.read_csv('./doce_octubre/doce_octubre_24.csv')
api_call_25 = pd.read_csv('./doce_octubre/doce_octubre_25.csv')
api_call_26 = pd.read_csv('./doce_octubre/doce_octubre_26.csv')
api_call_27 = pd.read_csv('./doce_octubre/doce_octubre_27.csv')
api_call_28 = pd.read_csv('./doce_octubre/doce_octubre_28.csv')
api_call_29 = pd.read_csv('./doce_octubre/doce_octubre_29.csv')
api_call_30 = pd.read_csv('./doce_octubre/doce_octubre_30.csv')
api_call_31 = pd.read_csv('./doce_octubre/doce_octubre_31.csv')
api_call_32 = pd.read_csv('./doce_octubre/doce_octubre_32.csv')
api_call_33 = pd.read_csv('./doce_octubre/doce_octubre_33.csv')
api_call_34 = pd.read_csv('./doce_octubre/doce_octubre_34.csv')
api_call_35 = pd.read_csv('./doce_octubre/doce_octubre_35.csv')

# %%
api_call_1.head()
# Out:
#    Unnamed: 0                                               link  rating  \
# 0           0  https://www.google.com/maps/reviews/data=!4m8!...     1.0
# 1           1  https://www.google.com/maps/reviews/data=!4m8!...     5.0
# 2           2  https://www.google.com/maps/reviews/data=!4m8!...     5.0
# 3           3  https://www.google.com/maps/reviews/data=!4m8!...     4.0
# 4           4  https://www.google.com/maps/reviews/data=!4m8!...     1.0
#
#            date  source                             review_id  \
# 0  12 hours ago  Google  ChdDSUhNMG9nS0VJQ0FnSUM5LUx1RTNRRRAB
# 1     a day ago  Google   ChZDSUhNMG9nS0VJQ0FnSUM5cUpqVFZREAE
# 2    2 days ago  Google  ChdDSUhNMG9nS0VJQ0FnSURkMzZpZHNRRRAB
# 3    2 days ago  Google   ChZDSUhNMG9nS0VJQ0FnSURkOTZXMFBnEAE
# 4    2 days ago  Google   ChZDSUhNMG9nS0VJQ0FnSURkOThDTFpnEAE
#
#                                              snippet  likes      user.name  \
# ...

# %%
if api_call_1['snippet'].equals(api_call_1['extracted_snippet.original']):
    print('Es igual')
else:
    print('Hay algo distinto')
# Out:
# Es igual

# %% [markdown]
# ## 1. Concat

# %%
len(api_call_10)
# Out:
# 10

# %%
df_doce_octubre = pd.concat([api_call_1,
                            api_call_2,
                            api_call_3,
                            api_call_4,
                            api_call_5,
                            api_call_6,
                            api_call_7,
                            api_call_8,
                            api_call_9,
                            api_call_10,
                            api_call_11,
                            api_call_12,
                            api_call_13,
                            api_call_14,
                            api_call_15,
                            api_call_16,
                            api_call_17,
                            api_call_18,
                            api_call_19,
                            api_call_20,
                            api_call_21,
                            api_call_22,
                            api_call_23,
                            api_call_24,
                            api_call_25,
                            api_call_26,
                            api_call_27,
                            api_call_28,
                            api_call_29,
                            api_call_30,
                            api_call_31,
                            api_call_32,
                            api_call_33,
                            api_call_34,
                            api_call_35,
                            ], sort=False, ignore_index=True)

# %%
df_doce_octubre
# Out:
#      Unnamed: 0                                               link  rating  \
# 0             0  https://www.google.com/maps/reviews/data=!4m8!...     1.0
# 1             1  https://www.google.com/maps/reviews/data=!4m8!...     5.0
# 2             2  https://www.google.com/maps/reviews/data=!4m8!...     5.0
# 3             3  https://www.google.com/maps/reviews/data=!4m8!...     4.0
# 4             4  https://www.google.com/maps/reviews/data=!4m8!...     1.0
# ..          ...                                                ...     ...
# 345           5  https://www.google.com/maps/reviews/data=!4m8!...     5.0
# 346           6  https://www.google.com/maps/reviews/data=!4m8!...     5.0
# 347           7  https://www.google.com/maps/reviews/data=!4m8!...     4.0
# 348           8  https://www.google.com/maps/reviews/data=!4m8!...     1.0
# 349           9  https://www.google.com/maps/reviews/data=!4m8!...     1.0
#
#              date  source                             review_id  \
# ...

# %%
df_doce_octubre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 22 columns):
#  #   Column                                                                                                                                                                                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                --------------  -----
# ...

# %%
df_doce_octubre.head(40)
# Out:
#     Unnamed: 0                                               link  rating  \
# 0            0  https://www.google.com/maps/reviews/data=!4m8!...     1.0
# 1            1  https://www.google.com/maps/reviews/data=!4m8!...     5.0
# 2            2  https://www.google.com/maps/reviews/data=!4m8!...     5.0
# 3            3  https://www.google.com/maps/reviews/data=!4m8!...     4.0
# 4            4  https://www.google.com/maps/reviews/data=!4m8!...     1.0
# 5            5  https://www.google.com/maps/reviews/data=!4m8!...     5.0
# 6            6  https://www.google.com/maps/reviews/data=!4m8!...     1.0
# 7            7  https://www.google.com/maps/reviews/data=!4m8!...     4.0
# 8            8  https://www.google.com/maps/reviews/data=!4m8!...     1.0
# 9            9  https://www.google.com/maps/reviews/data=!4m8!...     5.0
# 10           0  https://www.google.com/maps/reviews/data=!4m8!...     1.0
# 11           1  https://www.google.com/maps/reviews/data=!4m8!...     1.0
# ...

# %%
df_doce_octubre = df_doce_octubre.drop_duplicates(subset=['link'])

# %%
df_doce_octubre
# Out:
#      Unnamed: 0                                               link  rating  \
# 0             0  https://www.google.com/maps/reviews/data=!4m8!...     1.0
# 1             1  https://www.google.com/maps/reviews/data=!4m8!...     5.0
# 2             2  https://www.google.com/maps/reviews/data=!4m8!...     5.0
# 3             3  https://www.google.com/maps/reviews/data=!4m8!...     4.0
# 4             4  https://www.google.com/maps/reviews/data=!4m8!...     1.0
# ..          ...                                                ...     ...
# 345           5  https://www.google.com/maps/reviews/data=!4m8!...     5.0
# 346           6  https://www.google.com/maps/reviews/data=!4m8!...     5.0
# 347           7  https://www.google.com/maps/reviews/data=!4m8!...     4.0
# 348           8  https://www.google.com/maps/reviews/data=!4m8!...     1.0
# 349           9  https://www.google.com/maps/reviews/data=!4m8!...     1.0
#
#              date  source                             review_id  \
# ...

# %% [markdown]
# ## 2. Drop columns

# %%
df_doce_octubre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 343 entries, 0 to 349
# Data columns (total 22 columns):
#  #   Column                                                                                                                                                                                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                --------------  -----
# ...

# %%
drop_cols = ['Unnamed: 0',
             'link',
            'source',
            'review_id',
            'user.name',
            'user.link',
            'user.contributor_id',
            'user.thumbnail',
            'user.reviews',
            'extracted_snippet.original',
            'extracted_snippet.translated', 
            'images',
            'user.photos',
             #'response.date',
             #'response.snippet',
            #'response.extracted_snippet.original', 
            #'response.extracted_snippet.translated',
            'likes',
            'user.local_guide',
            'details.un_consejo_para_elena',
            'details.pd',
            'details.estoy_citada_para_la_tercera_dosis_y_he_llegado_a_las_2',
            'details.es_evidente_que_nos_cobran_de_nuestro_trabajo_y_esfuerzo_para_pagar_el_sueldo_de_estos_enfermeros_y_doctores_y_estos_aun_así_no_tienen_la_honorabilidad_de_atendernos_como_personas_y_más_en_situación_de_urgencia_como_toda_la_gente_que_ha_día_y_hora_de_hoy_22_03_2023_22']

# %%
df_doce_octubre = df_doce_octubre.drop(columns=[columna for columna in drop_cols if columna in df_doce_octubre.columns], errors='ignore')
print(f'Eliminadas las columnas innecesarias del DataFrame. Ahora cuenta con las siguientes columnas: ', len(df_doce_octubre.columns))
# Out:
# Eliminadas las columnas innecesarias del DataFrame. Ahora cuenta con las siguientes columnas:  3

# %%
df_doce_octubre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 343 entries, 0 to 349
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rating   343 non-null    float64
#  1   date     343 non-null    object
#  2   snippet  259 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 10.7+ KB

# %% [markdown]
# ## 3. Corrección en date

# %%
df_doce_octubre['date'].value_counts()
# Out:
# 2 months ago     41
# 8 months ago     35
# 5 months ago     34
# 10 months ago    31
# 11 months ago    30
# a month ago      30
# 4 months ago     27
# 3 months ago     27
# 6 months ago     21
# 9 months ago     19
# 7 months ago     14
# 2 weeks ago       7
# a year ago        6
# 3 weeks ago       6
# a week ago        6
# 2 days ago        3
# 4 weeks ago       2
# a day ago         1
# 6 days ago        1
# 4 days ago        1
# 12 hours ago      1
# Name: date, dtype: int64

# %%
fechas = {
    '12 hours ago': '2024-02-01',
    'a day ago': '2024-02-01',
    '4 days ago': '2024-02-01',
    '6 days ago': '2024-02-01',
    '2 days ago': '2024-02-01',
    'a week ago': '2024-02-01',
    '2 weeks ago': '2024-02-01',
    '3 weeks ago': '2024-02-01',
    '4 weeks ago': '2024-02-01',
    'a month ago': '2024-01-01',
    '2 months ago': '2023-12-01',
    '3 months ago': '2023-11-01',
    '4 months ago': '2023-10-01',
    '5 months ago': '2023-09-01',
    '6 months ago': '2023-08-01',
    '7 months ago': '2023-07-01',
    '8 months ago': '2023-06-01',
    '9 months ago': '2023-05-01',
    '10 months ago': '2023-04-01',
    '11 months ago': '2023-03-01',
    'a year ago': 'eliminar'
}

# %%
df_doce_octubre['Fecha'] = df_doce_octubre['date'].map(fechas).fillna(pd.to_datetime(df_doce_octubre['date'], errors='coerce'))

# %%
df_doce_octubre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 343 entries, 0 to 349
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rating   343 non-null    float64
#  1   date     343 non-null    object
#  2   snippet  259 non-null    object
#  3   Fecha    343 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 13.4+ KB

# %%
filas_nulas = df_doce_octubre[df_doce_octubre['Fecha'].isnull()]
print(filas_nulas)
# Out:
# Empty DataFrame
# Columns: [rating, date, snippet, Fecha]
# Index: []

# %%
df_doce_octubre = df_doce_octubre[df_doce_octubre['Fecha'] != 'eliminar']

# %%
df_doce_octubre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 337 entries, 0 to 343
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rating   337 non-null    float64
#  1   date     337 non-null    object
#  2   snippet  254 non-null    object
#  3   Fecha    337 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 13.2+ KB

# %%
df_doce_octubre.tail()
# Out:
#      rating           date                                            snippet  \
# 339     1.0  11 months ago  Esperas interminables y mucha falta de profesi...
# 340     5.0  11 months ago  Fui a urgencias por que se me cayó una señora ...
# 341     1.0  11 months ago  Una vergüenza de personal , les pido porfavor ...
# 342     5.0  11 months ago  Un 10 para las enfermeras y auxiliares de la 5...
# 343     4.0  11 months ago                                                NaN
#
#           Fecha
# 339  2023-03-01
# 340  2023-03-01
# 341  2023-03-01
# 342  2023-03-01
# 343  2023-03-01

# %%
df_doce_octubre.drop('date', axis=1, inplace=True)
# Out:
# C:\Users\tete1\AppData\Local\Temp\ipykernel_2712\1947918866.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_doce_octubre.drop('date', axis=1, inplace=True)

# %%
df_doce_octubre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 337 entries, 0 to 343
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rating   337 non-null    float64
#  1   snippet  254 non-null    object
#  2   Fecha    337 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 10.5+ KB

# %%
df_doce_octubre['Fecha'] = pd.to_datetime(df_doce_octubre['Fecha'])
# Out:
# C:\Users\tete1\AppData\Local\Temp\ipykernel_2712\2528205506.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_doce_octubre['Fecha'] = pd.to_datetime(df_doce_octubre['Fecha'])

# %%
df_doce_octubre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 337 entries, 0 to 343
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rating   337 non-null    float64
#  1   snippet  254 non-null    object
#  2   Fecha    337 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 10.5+ KB

# %%
df_doce_octubre.tail()
# Out:
#      rating                                            snippet      Fecha
# 339     1.0  Esperas interminables y mucha falta de profesi... 2023-03-01
# 340     5.0  Fui a urgencias por que se me cayó una señora ... 2023-03-01
# 341     1.0  Una vergüenza de personal , les pido porfavor ... 2023-03-01
# 342     5.0  Un 10 para las enfermeras y auxiliares de la 5... 2023-03-01
# 343     4.0                                                NaN 2023-03-01

# %% [markdown]
# ## 4. Nuevas columnas: Nombre establecimiento, Ciudad y Dirección

# %%
df_doce_octubre = df_doce_octubre.assign(Ciudad='Madrid', Dirección='Av. de Córdoba, s/n', Establecimiento='Hospital Universitario 12 de Octubre', CP=28041)

# %%
df_doce_octubre.head()
# Out:
#    rating                                            snippet      Fecha  \
# 0     1.0  Un avergüenza que tenga en la sala de espera m... 2024-02-01
# 1     5.0  Buen trato, nuevas instalaciones y lo último e... 2024-02-01
# 2     5.0                                                NaN 2024-02-01
# 3     4.0                                                NaN 2024-02-01
# 4     1.0                                                NaN 2024-02-01
#
#    Ciudad            Dirección                       Establecimiento     CP
# 0  Madrid  Av. de Córdoba, s/n  Hospital Universitario 12 de Octubre  28041
# 1  Madrid  Av. de Córdoba, s/n  Hospital Universitario 12 de Octubre  28041
# 2  Madrid  Av. de Córdoba, s/n  Hospital Universitario 12 de Octubre  28041
# 3  Madrid  Av. de Córdoba, s/n  Hospital Universitario 12 de Octubre  28041
# 4  Madrid  Av. de Córdoba, s/n  Hospital Universitario 12 de Octubre  28041

# %% [markdown]
# ## 5. Cambiar el datatype de rating a int64

# %%
df_doce_octubre['rating'] = df_doce_octubre['rating'].astype('int64')

# %%
df_doce_octubre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 337 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rating           337 non-null    int64
#  1   snippet          254 non-null    object
#  2   Fecha            337 non-null    datetime64[ns]
#  3   Ciudad           337 non-null    object
#  4   Dirección        337 non-null    object
#  5   Establecimiento  337 non-null    object
#  6   CP               337 non-null    int64
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 21.1+ KB

# %% [markdown]
# # Hosp. Univ. Clínic de Barcelona

# %%
api_call_1 = pd.read_csv('./clinic_barcelona/clinic_barcelona_1.csv')
api_call_2 = pd.read_csv('./clinic_barcelona/clinic_barcelona_2.csv')
api_call_3 = pd.read_csv('./clinic_barcelona/clinic_barcelona_3.csv')
api_call_4 = pd.read_csv('./clinic_barcelona/clinic_barcelona_4.csv')
api_call_5 = pd.read_csv('./clinic_barcelona/clinic_barcelona_5.csv')
api_call_6 = pd.read_csv('./clinic_barcelona/clinic_barcelona_6.csv')
api_call_7 = pd.read_csv('./clinic_barcelona/clinic_barcelona_7.csv')
api_call_8 = pd.read_csv('./clinic_barcelona/clinic_barcelona_8.csv')
api_call_9 = pd.read_csv('./clinic_barcelona/clinic_barcelona_9.csv')
api_call_10 = pd.read_csv('./clinic_barcelona/clinic_barcelona_10.csv')
api_call_11 = pd.read_csv('./clinic_barcelona/clinic_barcelona_11.csv')
api_call_12 = pd.read_csv('./clinic_barcelona/clinic_barcelona_12.csv')
api_call_13 = pd.read_csv('./clinic_barcelona/clinic_barcelona_13.csv')
api_call_14 = pd.read_csv('./clinic_barcelona/clinic_barcelona_14.csv')
api_call_15 = pd.read_csv('./clinic_barcelona/clinic_barcelona_15.csv')
api_call_16 = pd.read_csv('./clinic_barcelona/clinic_barcelona_16.csv')
api_call_17 = pd.read_csv('./clinic_barcelona/clinic_barcelona_17.csv')
api_call_18 = pd.read_csv('./clinic_barcelona/clinic_barcelona_18.csv')
api_call_19 = pd.read_csv('./clinic_barcelona/clinic_barcelona_19.csv')
api_call_20 = pd.read_csv('./clinic_barcelona/clinic_barcelona_20.csv')
api_call_21 = pd.read_csv('./clinic_barcelona/clinic_barcelona_21.csv')
api_call_22 = pd.read_csv('./clinic_barcelona/clinic_barcelona_22.csv')
api_call_23 = pd.read_csv('./clinic_barcelona/clinic_barcelona_23.csv')
api_call_24 = pd.read_csv('./clinic_barcelona/clinic_barcelona_24.csv')
api_call_25 = pd.read_csv('./clinic_barcelona/clinic_barcelona_25.csv')
api_call_26 = pd.read_csv('./clinic_barcelona/clinic_barcelona_26.csv')
api_call_27 = pd.read_csv('./clinic_barcelona/clinic_barcelona_27.csv')
api_call_28 = pd.read_csv('./clinic_barcelona/clinic_barcelona_28.csv')
api_call_29 = pd.read_csv('./clinic_barcelona/clinic_barcelona_29.csv')
api_call_30 = pd.read_csv('./clinic_barcelona/clinic_barcelona_30.csv')
api_call_31 = pd.read_csv('./clinic_barcelona/clinic_barcelona_31.csv')
api_call_32 = pd.read_csv('./clinic_barcelona/clinic_barcelona_32.csv')

# %%
df_clinic_bcn = pd.concat([api_call_1,
                            api_call_2,
                            api_call_3,
                            api_call_4,
                            api_call_5,
                            api_call_6,
                            api_call_7,
                            api_call_8,
                            api_call_9,
                            api_call_10,
                            api_call_11,
                            api_call_12,
                            api_call_13,
                             api_call_14,
                             api_call_15,
                             api_call_16,
                             api_call_17,
                             api_call_18,
                             api_call_19,
                             api_call_20,
                             api_call_21,
                             api_call_22,
                             api_call_23,
                             api_call_24,
                             api_call_25,
                             api_call_26,
                             api_call_27,
                              api_call_28,
                             api_call_29,
                             api_call_30,
                             api_call_31,
                              api_call_32], sort=False, ignore_index=True)

# %%
df_clinic_bcn.head()
# Out:
#    Unnamed: 0                                               link  rating  \
# 0           0  https://www.google.com/maps/reviews/data=!4m8!...     5.0
# 1           1  https://www.google.com/maps/reviews/data=!4m8!...     5.0
# 2           2  https://www.google.com/maps/reviews/data=!4m8!...     5.0
# 3           3  https://www.google.com/maps/reviews/data=!4m8!...     1.0
# 4           4  https://www.google.com/maps/reviews/data=!4m8!...     5.0
#
#           date  source                             review_id  \
# 0  6 hours ago  Google  ChdDSUhNMG9nS0VJQ0FnSUM5NXFPSGlBRRAB
# 1    a day ago  Google  ChdDSUhNMG9nS0VJQ0FnSUM5clBfaTRBRRAB
# 2   3 days ago  Google   ChZDSUhNMG9nS0VJQ0FnSUM5dU5XZUtREAE
# 3   5 days ago  Google   ChZDSUhNMG9nS0VJQ0FnSUM5b1B2M0tnEAE
# 4   6 days ago  Google   ChZDSUhNMG9nS0VJQ0FnSURkMV9qaVJREAE
#
#              user.name                                          user.link  \
# 0  Anna Sánchez Cantos  https://www.google.com/maps/contrib/1019976366...
# ...

# %%
df_clinic_bcn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 19 columns):
#  #   Column                                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                                  --------------  -----
#  0   Unnamed: 0                                                                                                                              320 non-null    int64
#  1   link                                                                                                                                    320 non-null    object
#  2   rating                                                                                                                                  320 non-null    float64
# ...

# %%
drop_cols = ['Unnamed: 0',
             'link',
             'images',
            'source',
            'review_id',
            'user.name',
            'user.link',
            'user.contributor_id',
            'user.thumbnail',
            'user.reviews',
            'extracted_snippet.original',
            'extracted_snippet.translated', 
            'user.photos',
            #'response.extracted_snippet.original', 
            #'response.extracted_snippet.translated',
            'likes',
            'user.local_guide',
            'details.también_una_vez_le_pregunté_que_qué_es_lo_que_podía_hacer_para_que_no_me_doliera_tanto_el_ojo_al_llorar_y_me_dijo_literalmente']
            #'details.nota_editada',
            #'details.en_resumen',
            #'details.no_me_deja_responderos_por_lo_que_edito_22_08_23_10']

# %%
df_clinic_bcn = df_clinic_bcn.drop(columns=[columna for columna in drop_cols if columna in df_clinic_bcn.columns], errors='ignore')
print(f'Eliminadas las columnas innecesarias del DataFrame. Ahora cuenta con las siguientes columnas: ', len(df_clinic_bcn.columns))
# Out:
# Eliminadas las columnas innecesarias del DataFrame. Ahora cuenta con las siguientes columnas:  3

# %%
df_clinic_bcn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rating   320 non-null    float64
#  1   date     320 non-null    object
#  2   snippet  273 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 7.6+ KB

# %%
df_clinic_bcn['date'].unique()
# Out:
# array(['6 hours ago', 'a day ago', '3 days ago', '5 days ago',
#        '6 days ago', 'a week ago', '2 weeks ago', '3 weeks ago',
#        '4 weeks ago', 'a month ago', '2 months ago', '3 months ago',
#        '4 months ago', '5 months ago', '6 months ago', '7 months ago',
#        '8 months ago', '9 months ago', '10 months ago', '11 months ago',
#        'a year ago'], dtype=object)

# %%
fechas = {
    #'an hour ago': '2024-02-01',
    '6 hours ago': '2024-02-12',
    'a day ago': '2024-02-01',
    '3 days ago': '2024-02-01',
    '5 days ago': '2024-02-01',
    '6 days ago': '2024-02-01',
    'a week ago': '2024-02-01',
    '2 weeks ago': '2024-02-01',
    '3 weeks ago': '2024-02-01',
    '4 weeks ago': '2024-02-01',
    'a month ago': '2024-01-01',
    '2 months ago': '2023-12-01',
    '3 months ago': '2023-11-01',
    '4 months ago': '2023-10-01',
    '5 months ago': '2023-09-01',
    '6 months ago': '2023-08-01',
    '7 months ago': '2023-07-01',
    '8 months ago': '2023-06-01',
    '9 months ago': '2023-05-01',
    '10 months ago': '2023-04-01',
    '11 months ago': '2023-03-01',
    'a year ago': 'eliminar'
}

# %%
df_clinic_bcn['Fecha'] = df_clinic_bcn['date'].map(fechas).fillna(pd.to_datetime(df_clinic_bcn['date'], errors='coerce'))

# %%
df_clinic_bcn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rating   320 non-null    float64
#  1   date     320 non-null    object
#  2   snippet  273 non-null    object
#  3   Fecha    320 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 10.1+ KB

# %%
df_clinic_bcn = df_clinic_bcn[df_clinic_bcn['Fecha'] != 'eliminar']

# %%
df_clinic_bcn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 312 entries, 0 to 311
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rating   312 non-null    float64
#  1   date     312 non-null    object
#  2   snippet  266 non-null    object
#  3   Fecha    312 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 12.2+ KB

# %%
df_clinic_bcn = df_clinic_bcn.assign(Ciudad='Barcelona', Dirección='Calle de Villarroel, 17', Establecimiento='Hospital Clínico de Barcelona', CP='08036')

# %%
df_clinic_bcn.head()
# Out:
#    rating         date                                            snippet  \
# 0     5.0  6 hours ago                                                NaN
# 1     5.0    a day ago  Todas las personas que se quejan y dan una est...
# 2     5.0   3 days ago  Hospital con especialistas muy cualificados , ...
# 3     1.0   5 days ago  Recientemente mi pareja a estado ingresada aqu...
# 4     5.0   6 days ago  A mí siempre me han atendido estupendamente en...
#
#         Fecha     Ciudad                Dirección  \
# 0  2024-02-12  Barcelona  Calle de Villarroel, 17
# 1  2024-02-01  Barcelona  Calle de Villarroel, 17
# 2  2024-02-01  Barcelona  Calle de Villarroel, 17
# 3  2024-02-01  Barcelona  Calle de Villarroel, 17
# 4  2024-02-01  Barcelona  Calle de Villarroel, 17
#
#                  Establecimiento     CP
# 0  Hospital Clínico de Barcelona  08036
# 1  Hospital Clínico de Barcelona  08036
# 2  Hospital Clínico de Barcelona  08036
# 3  Hospital Clínico de Barcelona  08036
# ...

# %%
df_clinic_bcn.drop('date', axis=1, inplace=True)

# %%
df_clinic_bcn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 312 entries, 0 to 311
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rating           312 non-null    float64
#  1   snippet          266 non-null    object
#  2   Fecha            312 non-null    object
#  3   Ciudad           312 non-null    object
#  4   Dirección        312 non-null    object
#  5   Establecimiento  312 non-null    object
#  6   CP               312 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 19.5+ KB

# %%
df_clinic_bcn['rating'] = df_clinic_bcn['rating'].astype('int64')

# %%
df_clinic_bcn['Fecha'] = pd.to_datetime(df_clinic_bcn['Fecha'])

# %%
df_clinic_bcn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 312 entries, 0 to 311
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rating           312 non-null    int64
#  1   snippet          266 non-null    object
#  2   Fecha            312 non-null    datetime64[ns]
#  3   Ciudad           312 non-null    object
#  4   Dirección        312 non-null    object
#  5   Establecimiento  312 non-null    object
#  6   CP               312 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 19.5+ KB

# %% [markdown]
# # Hosp. Univ. Vall d'Hebrón

# %%
api_call_1 = pd.read_csv('./vall/vall_1.csv')
api_call_2 = pd.read_csv('./vall/vall_2.csv')
api_call_3 = pd.read_csv('./vall/vall_3.csv')
api_call_4 = pd.read_csv('./vall/vall_4.csv')
api_call_5 = pd.read_csv('./vall/vall_5.csv')
api_call_6 = pd.read_csv('./vall/vall_6.csv')
api_call_7 = pd.read_csv('./vall/vall_7.csv')
api_call_8 = pd.read_csv('./vall/vall_8.csv')
api_call_9 = pd.read_csv('./vall/vall_9.csv')
api_call_10 = pd.read_csv('./vall/vall_10.csv')
api_call_11 = pd.read_csv('./vall/vall_11.csv')
api_call_12 = pd.read_csv('./vall/vall_12.csv')
api_call_13 = pd.read_csv('./vall/vall_13.csv')
api_call_14 = pd.read_csv('./vall/vall_14.csv')
api_call_15 = pd.read_csv('./vall/vall_15.csv')
api_call_16 = pd.read_csv('./vall/vall_16.csv')
api_call_17 = pd.read_csv('./vall/vall_17.csv')
api_call_18 = pd.read_csv('./vall/vall_18.csv')

# %%
df_vall = pd.concat([api_call_1,
                            api_call_2,
                            api_call_3,
                            api_call_4,
                            api_call_5,
                            api_call_6,
                            api_call_7,
                            api_call_8,
                            api_call_9,
                            api_call_10,
                            api_call_11,
                            api_call_12,
                            api_call_13,
                             api_call_14,
                             api_call_15,
                             api_call_16,
                             api_call_17,
                             api_call_18], sort=False, ignore_index=True)

# %%
df_vall.head()
# Out:
#    Unnamed: 0                                               link  rating  \
# 0           0  https://www.google.com/maps/reviews/data=!4m8!...     1.0
# 1           1  https://www.google.com/maps/reviews/data=!4m8!...     1.0
# 2           2  https://www.google.com/maps/reviews/data=!4m8!...     1.0
# 3           3  https://www.google.com/maps/reviews/data=!4m8!...     5.0
# 4           4  https://www.google.com/maps/reviews/data=!4m8!...     5.0
#
#           date  source                             review_id  \
# 0  3 hours ago  Google  ChdDSUhNMG9nS0VJQ0FnSUM5MXRXTy1BRRAB
# 1    a day ago  Google  ChdDSUhNMG9nS0VJQ0FnSUM5Mm9iZzNBRRAB
# 2    a day ago  Google   ChZDSUhNMG9nS0VJQ0FnSUM5ekpfRFd3EAE
# 3   2 days ago  Google  ChdDSUhNMG9nS0VJQ0FnSUM5akoydmtnRRAB
# 4   3 days ago  Google   ChZDSUhNMG9nS0VJQ0FnSUM5LU4tZ1dnEAE
#
#                                              snippet       user.name  \
# 0     Impossible contactar per telèfon, una vergonya    Olga Barbens
# ...

# %%
df_vall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 20 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   Unnamed: 0                                                                   180 non-null    int64
#  1   link                                                                         180 non-null    object
#  2   rating                                                                       180 non-null    float64
#  3   date                                                                         180 non-null    object
#  4   source                                                                       180 non-null    object
#  5   review_id                                                                    180 non-null    object
# ...

# %%
drop_cols = ['Unnamed: 0',
                 'link',
                'source',
                'review_id',
                'user.name',
                'user.link',
                'user.contributor_id',
                'user.thumbnail',
             'user.local_guide',
                'user.reviews',
             'user.photos',
                'extracted_snippet.original',
                'extracted_snippet.translated',
                'likes',
                'details.gracias_hijos_si_mi_ex_reseñas_de_él_léanlas_me_salieron_sin_buscar',
                'details.me_decía',
            'images']
                #'details.no_me_deja_responderos_por_lo_que_edito_22_08_23_10']
df_vall = df_vall.drop(columns=[columna for columna in drop_cols if columna in df_vall.columns], errors='ignore')
print(f'Eliminadas las columnas innecesarias del DataFrame. Ahora cuenta con las siguientes columnas: ', len(df_vall.columns))
# Out:
# Eliminadas las columnas innecesarias del DataFrame. Ahora cuenta con las siguientes columnas:  3

# %%
df_vall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rating   180 non-null    float64
#  1   date     180 non-null    object
#  2   snippet  155 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 4.3+ KB

# %%
df_vall['date'].unique()
# Out:
# array(['3 hours ago', 'a day ago', '2 days ago', '3 days ago',
#        '4 days ago', '6 days ago', 'a week ago', '2 weeks ago',
#        '3 weeks ago', 'a month ago', '2 months ago', '3 months ago',
#        '4 months ago', '5 months ago', '6 months ago', '7 months ago',
#        '8 months ago', '9 months ago', '10 months ago', '11 months ago',
#        'a year ago'], dtype=object)

# %%
fechas = {
    '3 hours ago': '2024-02-12',
    'a day ago': '2024-02-01',
    '2 days ago': '2024-02-01',
    '3 days ago': '2024-02-01',
    '4 days ago': '2024-02-01',
    '6 days ago': '2024-02-01',
    'a week ago': '2024-02-01',
    '2 weeks ago': '2024-02-01',
    '3 weeks ago': '2024-02-01',
    #'4 weeks ago': '2024-02-01',
    'a month ago': '2024-01-01',
    '2 months ago': '2023-12-01',
    '3 months ago': '2023-11-01',
    '4 months ago': '2023-10-01',
    '5 months ago': '2023-09-01',
    '6 months ago': '2023-08-01',
    '7 months ago': '2023-07-01',
    '8 months ago': '2023-06-01',
    '9 months ago': '2023-05-01',
    '10 months ago': '2023-04-01',
    '11 months ago': '2023-03-01',
    'a year ago': 'eliminar'
}

# %%
df_vall['Fecha'] = df_vall['date'].map(fechas).fillna(pd.to_datetime(df_vall['date'], errors='coerce'))

# %%
df_vall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rating   180 non-null    float64
#  1   date     180 non-null    object
#  2   snippet  155 non-null    object
#  3   Fecha    180 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 5.8+ KB

# %%
df_vall = df_vall[df_vall['Fecha'] != 'eliminar']

# %%
df_vall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 176 entries, 0 to 175
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rating   176 non-null    float64
#  1   date     176 non-null    object
#  2   snippet  151 non-null    object
#  3   Fecha    176 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 6.9+ KB

# %%
df_vall.drop('date', axis=1, inplace=True)

# %%
df_vall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 176 entries, 0 to 175
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rating   176 non-null    float64
#  1   snippet  151 non-null    object
#  2   Fecha    176 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 5.5+ KB

# %%
df_vall['rating'] = df_vall['rating'].astype('int64')

# %%
df_vall['Fecha'] = pd.to_datetime(df_vall['Fecha'])

# %%
df_vall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 176 entries, 0 to 175
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rating   176 non-null    int64
#  1   snippet  151 non-null    object
#  2   Fecha    176 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 5.5+ KB

# %%
df_vall = df_vall.assign(Ciudad='Barcelona', Dirección="Passeig de la Vall d'Hebron", Establecimiento='Hospital Universitario Valle de Hebrón', CP='08035')

# %%
df_vall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 176 entries, 0 to 175
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rating           176 non-null    int64
#  1   snippet          151 non-null    object
#  2   Fecha            176 non-null    datetime64[ns]
#  3   Ciudad           176 non-null    object
#  4   Dirección        176 non-null    object
#  5   Establecimiento  176 non-null    object
#  6   CP               176 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 11.0+ KB

# %%
df_vall.tail()
# Out:
#      rating                                            snippet      Fecha  \
# 171       5            Enca tadora muy amables y profesionales 2023-03-01
# 172       5  Me sorprende lo bien organizado que está el mó... 2023-03-01
# 173       5  És del millor que tenim. No hi perdem mai. Grà... 2023-03-01
# 174       1  Atenció telefònica nefasta. Tel. 934893000. Se... 2023-03-01
# 175       1  La atención telefónica es pésima, te tratan de... 2023-03-01
#
#         Ciudad                    Dirección  \
# 171  Barcelona  Passeig de la Vall d'Hebron
# 172  Barcelona  Passeig de la Vall d'Hebron
# 173  Barcelona  Passeig de la Vall d'Hebron
# 174  Barcelona  Passeig de la Vall d'Hebron
# 175  Barcelona  Passeig de la Vall d'Hebron
#
#                             Establecimiento     CP
# 171  Hospital Universitario Valle de Hebrón  08035
# 172  Hospital Universitario Valle de Hebrón  08035
# 173  Hospital Universitario Valle de Hebrón  08035
# ...

# %% [markdown]
# # Paso final: un único Excel con todos

# %%
df_clinic_bcn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 312 entries, 0 to 311
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rating           312 non-null    int64
#  1   snippet          266 non-null    object
#  2   Fecha            312 non-null    datetime64[ns]
#  3   Ciudad           312 non-null    object
#  4   Dirección        312 non-null    object
#  5   Establecimiento  312 non-null    object
#  6   CP               312 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 19.5+ KB

# %%
df_doce_octubre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 337 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rating           337 non-null    int64
#  1   snippet          254 non-null    object
#  2   Fecha            337 non-null    datetime64[ns]
#  3   Ciudad           337 non-null    object
#  4   Dirección        337 non-null    object
#  5   Establecimiento  337 non-null    object
#  6   CP               337 non-null    int64
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 21.1+ KB

# %%
df_vall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 176 entries, 0 to 175
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rating           176 non-null    int64
#  1   snippet          151 non-null    object
#  2   Fecha            176 non-null    datetime64[ns]
#  3   Ciudad           176 non-null    object
#  4   Dirección        176 non-null    object
#  5   Establecimiento  176 non-null    object
#  6   CP               176 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 11.0+ KB

# %%
df_full_hospitals = pd.concat([df_clinic_bcn,
                              df_doce_octubre,
                              df_vall], sort=False, ignore_index=True)

# %%
df_full_hospitals
# Out:
#      rating                                            snippet      Fecha  \
# 0         5                                                NaN 2024-02-12
# 1         5  Todas las personas que se quejan y dan una est... 2024-02-01
# 2         5  Hospital con especialistas muy cualificados , ... 2024-02-01
# 3         1  Recientemente mi pareja a estado ingresada aqu... 2024-02-01
# 4         5  A mí siempre me han atendido estupendamente en... 2024-02-01
# ..      ...                                                ...        ...
# 820       5            Enca tadora muy amables y profesionales 2023-03-01
# 821       5  Me sorprende lo bien organizado que está el mó... 2023-03-01
# 822       5  És del millor que tenim. No hi perdem mai. Grà... 2023-03-01
# 823       1  Atenció telefònica nefasta. Tel. 934893000. Se... 2023-03-01
# 824       1  La atención telefónica es pésima, te tratan de... 2023-03-01
#
#         Ciudad                    Dirección  \
# ...

# %%
len(df_clinic_bcn)+len(df_doce_octubre)+len(df_vall)
# Out:
# 825

# %%
len(df_full_hospitals)
# Out:
# 825

# %%
df_full_hospitals.to_excel('../reviews/hosp_alta.xlsx')
