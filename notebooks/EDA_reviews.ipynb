# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Reviews de 2018

# %%
reviews2018 = pd.read_csv('../our_reviews/clean_2018.csv')

# %%
reviews2018.head()
# Out:
#                      Fecha                  Nombre del establecimiento  \
# 0  2018-03-07 07:18:08.931  Hospital Universitari General de Catalunya
# 1  2018-03-05 11:25:50.957  Hospital Universitari General de Catalunya
# 2  2018-02-21 07:27:34.697  Hospital Universitari General de Catalunya
# 3  2018-02-19 10:17:56.154  Hospital Universitari General de Catalunya
# 4  2018-02-15 13:11:35.813  Hospital Universitari General de Catalunya
#
#             groups              Dirección                 Ciudad  \
# 0  Cataluña, Hospi  Calle Pedro I Pons, 1  Sant Cugat Del Vallès
# 1  Cataluña, Hospi  Calle Pedro I Pons, 1  Sant Cugat Del Vallès
# 2  Cataluña, Hospi  Calle Pedro I Pons, 1  Sant Cugat Del Vallès
# 3  Cataluña, Hospi  Calle Pedro I Pons, 1  Sant Cugat Del Vallès
# 4  Cataluña, Hospi  Calle Pedro I Pons, 1  Sant Cugat Del Vallès
#
#   Código postal                                            content  rating  \
# ...

# %%
reviews2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3156 entries, 0 to 3155
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Fecha                       3156 non-null   object
#  1   Nombre del establecimiento  3156 non-null   object
#  2   groups                      3156 non-null   object
#  3   Dirección                   3156 non-null   object
#  4   Ciudad                      3156 non-null   object
#  5   Código postal               3156 non-null   object
#  6   content                     2329 non-null   object
#  7   rating                      3156 non-null   int64
#  8   Tipografía                  3156 non-null   object
#  9   Territorio                  3156 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 246.7+ KB

# %%
len(reviews2018['Nombre del establecimiento'].unique())
# Out:
# 102

# %% [markdown]
# ### Breve descripción:
# - En 2018 tenemos un total de 3.155 reseñas divididas en 102 establecimientos

# %%
y = reviews2018['rating'].value_counts().tolist()
x = reviews2018['rating'].value_counts().keys().tolist()
print(valores)
print(etiquetas)
# Out:
# [1271, 1152, 360, 202, 171]
# [1, 5, 4, 3, 2]

# %%
colores = ["#E37868", "#68E378", "#68E378", "#E3B568", "#E37868"]
fig, ax = plt.subplots()
ax.bar(x,y, color=colores)
ax.set_title('Cantidad de reseñas por rating en 2018')
plt.show;

# %% [markdown]
# # Reviews 2019

# %%
reviews2019 = pd.read_csv('../our_reviews/clean_2019.csv')

# %%
reviews2019.head()
# Out:
#                      Fecha                 Nombre del establecimiento  \
# 0  2019-11-26 16:45:20.857                Hospital Quirónsalud Murcia
# 1  2019-11-24 19:58:52.837                Hospital Quirónsalud Murcia
# 2  2019-11-16 18:11:47.256                Hospital Quirónsalud Murcia
# 3  2019-10-29 13:09:07.085  Hospital Universitario Quirónsalud Madrid
# 4  2019-05-26 09:13:23.909             Hospital Quirónsalud Barcelona
#
#                    groups                   Dirección              Ciudad  \
# 0          Levante, Hospi  Calle Miguel Hernández, 12              Murcia
# 1          Levante, Hospi  Calle Miguel Hernández, 12              Murcia
# 2          Levante, Hospi  Calle Miguel Hernández, 12              Murcia
# 3  Madrid Privados, Hospi    C. Diego de Velázquez, 1  Pozuelo De Alarcón
# 4         Cataluña, Hospi    Plaza Alfonso Comin, 5-7           Barcelona
#
#   Código postal                                            content  rating  \
# ...

# %%
reviews2019['Fecha'].min()
reviews2019['Fecha'].max()
# Out:
# '2019-12-31 17:59:14.755'

# %%
reviews2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4359 entries, 0 to 4358
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Fecha                       4359 non-null   object
#  1   Nombre del establecimiento  4359 non-null   object
#  2   groups                      4359 non-null   object
#  3   Dirección                   4359 non-null   object
#  4   Ciudad                      4359 non-null   object
#  5   Código postal               4359 non-null   object
#  6   content                     3384 non-null   object
#  7   rating                      4359 non-null   int64
#  8   Tipografía                  4359 non-null   object
#  9   Territorio                  4359 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 340.7+ KB

# %%
len(reviews2019['Nombre del establecimiento'].unique())
# Out:
# 108

# %% [markdown]
# ### Breve resumen
# En 2019 tenemos un total de 4.359 reseñas repartidas en 108 establecimientos

# %%
y = reviews2019['rating'].value_counts().tolist()
x = reviews2019['rating'].value_counts().keys().tolist()
print(y)
print(x)
# Out:
# [1825, 1655, 446, 221, 212]
# [1, 5, 4, 3, 2]

# %%
colores = ["#E37868", "#68E378", "#68E378", "#E3B568", "#E37868"]
fig, ax = plt.subplots()
ax.bar(x,y, color=colores)
ax.set_title('Cantidad de reseñas por rating en 2019')
plt.show;

# %% [markdown]
# # Reviews 2020

# %%
reviews2020 = pd.read_csv('../our_reviews/clean_2020.csv')

# %%
reviews2020.head()
# Out:
#                      Fecha     Nombre del establecimiento            groups  \
# 0  2020-12-21 09:18:14.356    Hospital Quirónsalud Málaga  Andalucía, Hospi
# 1  2020-08-10 09:31:30.084  Hospital Quirónsalud Valencia    Levante, Hospi
# 2  2020-08-08 11:07:58.531           Quirónsalud Alicante    Levante, Hospi
# 3  2020-07-30 19:56:08.596  Hospital Quirónsalud Valencia    Levante, Hospi
# 4  2020-07-23 00:34:06.458  Hospital Quirónsalud Valencia    Levante, Hospi
#
#                        Dirección              Ciudad  Código postal  \
# 0       Av. Imperio Argentina, 1              Málaga          29004
# 1  Avinguda De Blasco Ibáñez, 14            València          46010
# 2        Calle Cruz De Piedra, 4  Alicante (Alacant)           3015
# 3  Avinguda De Blasco Ibáñez, 14            València          46010
# 4  Avinguda De Blasco Ibáñez, 14            València          46010
#
#                                              content  rating Tipografía  \
# ...

# %%
reviews2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4313 entries, 0 to 4312
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Fecha                       4313 non-null   object
#  1   Nombre del establecimiento  4313 non-null   object
#  2   groups                      4313 non-null   object
#  3   Dirección                   4313 non-null   object
#  4   Ciudad                      4313 non-null   object
#  5   Código postal               4313 non-null   int64
#  6   content                     3391 non-null   object
#  7   rating                      4313 non-null   int64
#  8   Tipografía                  4313 non-null   object
#  9   Territorio                  4313 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 337.1+ KB

# %%
len(reviews2020['Nombre del establecimiento'].unique())
# Out:
# 118

# %% [markdown]
# ### Breve descripción
# - En 2020 tenemos un total de 4.313 reseñas en 118 establecimientos

# %%
y = reviews2020['rating'].value_counts().tolist()
x = reviews2020['rating'].value_counts().keys().tolist()
print(x)
print(y)
# Out:
# [1, 5, 4, 2, 3]
# [2089, 1381, 417, 232, 194]

# %%
colores = ["#E37868", "#68E378", "#68E378", "#E37868", "#E3B568"]
fig, ax = plt.subplots()
ax.bar(x,y, color=colores)
ax.set_title('Cantidad de reseñas por rating en 2020')
plt.show;

# %% [markdown]
# # Reviews 2021

# %%
reviews2021 = pd.read_csv('../our_reviews/clean_2021.csv')

# %%
reviews2021.head()
# Out:
#                      Fecha                         Nombre del establecimiento  \
# 0  2021-04-16 10:14:07.046  Centro Médico Quirónsalud Valle del Henares (A...
# 1  2021-04-14 08:50:58.371  Centro Médico Quirónsalud Valle del Henares (A...
# 2  2021-10-14 10:06:35.366                     Grupo Hospitalario Quirónsalud
# 3  2021-07-16 10:43:25.060                     Grupo Hospitalario Quirónsalud
# 4  2021-04-27 15:28:10.506                     Grupo Hospitalario Quirónsalud
#
#                      groups                      Dirección             Ciudad  \
# 0  Madrid Privados, Centros  Calle República Dominicana, 6  Alcalá De Henares
# 1  Madrid Privados, Centros  Calle República Dominicana, 6  Alcalá De Henares
# 2                     Otros             C. de Zurbarán, 28             Madrid
# 3                     Otros             C. de Zurbarán, 28             Madrid
# 4                     Otros             C. de Zurbarán, 28             Madrid
#
# ...

# %%
reviews2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8068 entries, 0 to 8067
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Fecha                       8068 non-null   object
#  1   Nombre del establecimiento  8068 non-null   object
#  2   groups                      8068 non-null   object
#  3   Dirección                   8068 non-null   object
#  4   Ciudad                      8068 non-null   object
#  5   Código postal               8068 non-null   object
#  6   content                     6764 non-null   object
#  7   rating                      8068 non-null   int64
#  8   Tipografía                  8068 non-null   object
#  9   Territorio                  8068 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 630.4+ KB

# %%
reviews2021['Fecha'].min()
reviews2021['Fecha'].max()
# Out:
# '2021-12-31 22:37:35.639'

# %%
len(reviews2021['Nombre del establecimiento'].unique())
# Out:
# 129

# %% [markdown]
# ### Breve descripción
# En 2021 tenemos un total de 8.068 reseñas en 129 establecimientos

# %%
y = reviews2021['rating'].value_counts().tolist()
x = reviews2021['rating'].value_counts().keys().tolist()
print(x)
print(y)
# Out:
# [1, 5, 4, 2, 3]
# [4184, 2556, 612, 390, 326]

# %%
colores = ["#E37868", "#68E378", "#68E378", "#E37868", "#E3B568"]
fig, ax = plt.subplots()
ax.bar(x,y, color=colores)
ax.set_title('Cantidad de reseñas por rating en 2021')
plt.show;

# %% [markdown]
# # Reviews en 2022

# %%
reviews2022 = pd.read_csv('../our_reviews/clean_2022.csv')

# %%
reviews2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14250 entries, 0 to 14249
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Fecha                       14250 non-null  object
#  1   Nombre del establecimiento  14250 non-null  object
#  2   groups                      14250 non-null  object
#  3   Dirección                   14250 non-null  object
#  4   Ciudad                      14250 non-null  object
#  5   Código postal               14250 non-null  object
#  6   content                     11355 non-null  object
#  7   rating                      14250 non-null  int64
#  8   Tipografía                  14250 non-null  object
#  9   Territorio                  14250 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.1+ MB

# %%
reviews2022.head()
# Out:
#                      Fecha                         Nombre del establecimiento  \
# 0  2022-11-25 14:13:39.419                 Centro Médico Quirónsalud A Coruña
# 1  2022-03-28 06:35:09.549               Hospital de Día Quirónsalud Donostia
# 2  2022-12-12 09:33:47.138                   Hospital Quirónsalud Palmaplanas
# 3  2022-10-28 06:39:31.061  Laboratorio Análisis Clínicos – Hospital Unive...
# 4  2022-06-05 15:06:34.937                           Hospital Quirónsalud Sur
#
#                           groups                   Dirección  \
# 0               Galicia, Centros        Calle Manuel Murguía
# 1  País Vasco y Navarra, Centros         Calle De Alkolea, 7
# 2                Baleares, Hospi          Camí Del Reis, 308
# 3                Cataluña, Otros  Carrer de Sabino Arana, 24
# 4         Madrid Privados, Hospi          Calle Estambul, 30
#
#                     Ciudad Código postal  \
# 0                 A Coruña         15011
# 1  Donostia- San Sebastián         20012
# ...

# %%
len(reviews2022['Nombre del establecimiento'].unique())
# Out:
# 138

# %% [markdown]
# ### Breve descrpción
# En 2022 tenemos un total de 14.250 reseñas repartidas en 138 establecimientos

# %%
y = reviews2022['rating'].value_counts().tolist()
x = reviews2022['rating'].value_counts().keys().tolist()
print(x)
print(y)
# Out:
# [1, 5, 4, 2, 3]
# [6102, 5973, 1188, 551, 436]

# %%
colores = ["#E37868", "#68E378", "#68E378", "#E37868", "#E3B568"]
fig, ax = plt.subplots()
ax.bar(x,y, color=colores)
ax.set_title('Cantidad de reseñas por rating en 2022')
plt.show;

# %% [markdown]
# # Reviews de 2023

# %%
reviews2023 = pd.read_csv('../our_reviews/clean_2023.csv')

# %%
reviews2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23424 entries, 0 to 23423
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Territorio                  23424 non-null  object
#  1   Tipografía                  23424 non-null  object
#  2   Fecha                       23424 non-null  object
#  3   Nombre del establecimiento  23424 non-null  object
#  4   Dirección                   23424 non-null  object
#  5   Ciudad                      23424 non-null  object
#  6   Código postal               23424 non-null  object
#  7   content                     18035 non-null  object
#  8   rating                      23424 non-null  int64
#  9   tags                        23424 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.8+ MB

# %%
len(reviews2023['Nombre del establecimiento'].unique())
# Out:
# 151

# %% [markdown]
# ### Breve description:
# En 2023 tenemos un total de 23.424 reseñas repartidas en 151 establecimientos.

# %%
y = reviews2023['rating'].value_counts().tolist()
x = reviews2023['rating'].value_counts().keys().tolist()
print(x)
print(y)
# Out:
# [5, 1, 4, 2, 3]
# [13823, 6545, 1860, 632, 564]

# %%
colores = ["#68E378", "#E37868", "#68E378", "#E37868", "#E3B568"]
fig, ax = plt.subplots()
ax.bar(x,y, color=colores)
ax.set_title('Cantidad de reseñas por rating en 2023')
plt.show;

# %%
lista2023 = reviews2023['Nombre del establecimiento'].unique().tolist()
lista2018 = reviews2018['Nombre del establecimiento'].unique().tolist()

# %%
listatotal = lista2023 != lista2018
print(listatotal)
# Out:
# True

# %%
list(e for e in lista2023 if e not in lista2018)
list(e for e in lista2018 if e not in lista2023)
list(e for e in lista2023 if e not in lista2018)+list(e for e in lista2018 if e not in lista2023)
# Out:
# ['Instituto de Neuro-rehabilitación Quirónsalud Pontevedra',
#  'Instituto Oncológico Quirónsalud Zaragoza',
#  'Centro de Rehabilitación Ruber Juan Bravo',
#  'Consultas Externas Hospital Quirónsalud San José',
#  'Centro Médico Quirónsalud Algeciras',
#  'Centro Médico Quirónsalud Marbella',
#  'Centro Médico Quirónsalud Guadalete',
#  'Centro Médico Quirónsalud Espartinas',
#  'Centro Médico Quirónsalud Artes Gráficas',
#  'Centro M. Quirónsalud Almendralejo',
#  'Centro M. Quirónsalud Don Benito',
#  'Quirónsalud Dental Manacor',
#  'Centro Médico Quirónsalud Manacor',
#  'Hospital El Pilar – Consultas Externas Alfonso XII',
#  'Hospital El Pilar – Consultas Externas Balmes',
#  'Centro Médico Quirónsalud Dígest Laietania',
#  'Centro de Oftalmología Quirónsalud Marbella',
#  'Centro Médico Quirónsalud Costa del Sol',
#  'Centro Médico Quirónsalud Severo Ochoa',
#  'Centro de Rehabilitación Quirónsalud Vitoria',
#  'Hospital Quirónsalud Lugo',
# ...

# %%
count_2018 = len(reviews2018.groupby('Fecha').size())
count_2019 = len(reviews2019.groupby('Fecha').size())
count_2020 = len(reviews2020.groupby('Fecha').size())
count_2021 = len(reviews2021.groupby('Fecha').size())
count_2022 = len(reviews2022.groupby('Fecha').size())
count_2023 = len(reviews2023.groupby('Fecha').size())

# %%
plt.figure(figsize=(4,8))
fig, ax = plt.subplots()
ax.bar(count_2018, count_2018, color=colores)
# Out:
# <BarContainer object of 1 artists>

# %%
pip install wordcloud
# Out:
# ...
#    ---------------------------------------- 0.0/300.7 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.7 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.7 kB ? eta -:--:--
#    ---------- ---------------------------- 81.9/300.7 kB 770.8 kB/s eta 0:00:01
#    ----------------------------- ---------- 225.3/300.7 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 300.7/300.7 kB 1.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script wordcloud_cli.exe is installed in 'C:\Users\tete1\miniconda3\envs\m2_env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
reviews2018["content"] = reviews2018["content"].fillna(value="")

# %%
word_string=" ".join(reviews2018["content"].str.lower())

# %%
plt.figure(figsize=(15,15))
wc = WordCloud(stopwords = stop_words, max_words=100, max_font_size= 300,  width=1600, height=800)
wc.generate(word_string)

plt.imshow(wc.recolor( colormap= 'viridis' , random_state=17), interpolation="bilinear")
plt.axis('off')
# Out:
# (-0.5, 1599.5, 799.5, -0.5)

# %%
stop_words = ['a', 
            'ante',
            'sobre',
            'de',
            'desde',
            'y',
            'un',
            'una',
            'translated',
             'by google',
             'is not',
             'and',
             'in',
             'the',
             'que',
             'me',
             'con',
             'this',
             'his',
             'her',
             'have',
             'for',
             'para',
             'on',
             'en',
             'with',
             'no',
             'of',
             'it']

# %%
text = reviews2018['content'].values

wordcloud = WordCloud().generate(str(text))

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud)
plt.axis("off")
plt.show();

# %% [markdown]
# # Documentación y más información
#
# https://medium.com/@humeyraboluk/reviews-analysis-with-python-bd5e3f016fdf

# %%
reviews2023 = pd.read_csv('../our_reviews/clean_2023.csv')

# %%
infanta_elena = reviews2023[reviews2023['Nombre del establecimiento'] == 'Hospital Universitario Infanta Elena']

# %%
infanta_elena
# Out:
#             Territorio Tipografía                    Fecha  \
# 19571  Públicos Madrid   Hospital  2023-12-31 18:35:21.222
# 19572  Públicos Madrid   Hospital  2023-12-31 17:36:48.665
# 19573  Públicos Madrid   Hospital  2023-12-31 11:46:35.368
# 19574  Públicos Madrid   Hospital  2023-12-31 08:43:34.056
# 19575  Públicos Madrid   Hospital  2023-12-30 04:02:18.452
# ...                ...        ...                      ...
# 20175  Públicos Madrid   Hospital  2023-01-02 16:46:02.645
# 20176  Públicos Madrid   Hospital  2023-01-02 08:31:36.481
# 20177  Públicos Madrid   Hospital  2023-01-02 07:47:05.079
# 20178  Públicos Madrid   Hospital  2023-01-01 15:14:51.255
# 20179  Públicos Madrid   Hospital  2023-01-01 04:34:48.166
#
#                  Nombre del establecimiento  \
# 19571  Hospital Universitario Infanta Elena
# 19572  Hospital Universitario Infanta Elena
# 19573  Hospital Universitario Infanta Elena
# 19574  Hospital Universitario Infanta Elena
# ...

# %%
len(infanta_elena)
# Out:
# 609
